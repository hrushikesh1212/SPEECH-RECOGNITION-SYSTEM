# %%
# !pip install SpeechRecognition pyaudio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: SpeechRecognition in c:\users\hp\appdata\roaming\python\python312\site-packages (3.14.5)
# Requirement already satisfied: pyaudio in c:\users\hp\appdata\roaming\python\python312\site-packages (0.2.14)
# Requirement already satisfied: typing-extensions in c:\users\hp\appdata\roaming\python\python312\site-packages (from SpeechRecognition) (4.15.0)
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import speech_recognition as sr
import tkinter as tk

def recognize_speech():
    r = sr.Recognizer()
    
    with sr.Microphone() as source:
        status_label.config(text="Listening...")
        root.update()
        audio = r.listen(source)
    try:
        text = r.recognize_google(audio)
        text_box.insert(tk.END, text + "\n")
        status_label.config(text="Done")
        
        if text.lower() == "exit":
            root.destroy()

    except:
        status_label.config(text="Could not understand")
root = tk.Tk()
root.title("Simple Speech to Text")
root.geometry("400x300")
text_box = tk.Text(root)
text_box.pack(expand=True, fill="both")
status_label = tk.Label(root, text="Click Start and Speak")
status_label.pack()
start_button = tk.Button(root, text="Start", command=recognize_speech)
start_button.pack()
root.mainloop()
